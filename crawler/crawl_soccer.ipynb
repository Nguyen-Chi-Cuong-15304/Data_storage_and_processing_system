# %%
import re
import requests
import time
import pandas as pd
from bs4 import BeautifulSoup
from kafka import KafkaProducer
from kafka.admin import KafkaAdminClient, NewTopic
from kafka.errors import KafkaError
import json
import logging
import os
import signal
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter
from requests.exceptions import RequestException

# --- Cấu hình Logging ---
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[logging.StreamHandler()]
)
logger = logging.getLogger(__name__)

# --- Cấu hình Kafka ---
KAFKA_BROKER_URL = os.getenv('KAFKA_BROKER_URL', 'localhost:9092')
KAFKA_TOPIC = 'football_players'

# --- File paths ---
PATH_TO_LEAGUES = "Leagues.csv"
PATH_TO_CLUBS = "Clubs.csv"
PATH_TO_PLAYERS_LINK = "All_Players_Link.csv"
PATH_TO_FINAL_DATA = "Final_Data.csv"

# --- HTTP session với retry logic ---
session = requests.Session()
retries = Retry(total=3, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504])
session.mount('https://', HTTPAdapter(max_retries=retries))

# --- Headers cho requests ---
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/136.0.0.0 Safari/537.36",
    "accept-language": "en-US,en;q=0.9"
}

# --- Xử lý tín hiệu ngắt ---
producer = None

def signal_handler(sig, frame):
    logger.info("Received interrupt signal. Cleaning up...")
    if producer:
        producer.flush(timeout=60)
        producer.close()
    logger.info("Cleanup completed. Exiting.")
    exit(0)

signal.signal(signal.SIGINT, signal_handler)
signal.signal(signal.SIGTERM, signal_handler)

# --- Kiểm tra và tạo Kafka topic ---
def check_and_create_topic():
    try:
        admin_client = KafkaAdminClient(bootstrap_servers=[KAFKA_BROKER_URL])
        topic_list = admin_client.list_topics()
        if KAFKA_TOPIC not in topic_list:
            logger.info(f"Topic '{KAFKA_TOPIC}' does not exist. Creating...")
            new_topic = NewTopic(name=KAFKA_TOPIC, num_partitions=1, replication_factor=1)
            admin_client.create_topics(new_topics=[new_topic], validate_only=False)
            logger.info(f"Topic '{KAFKA_TOPIC}' created successfully.")
        else:
            logger.info(f"Topic '{KAFKA_TOPIC}' already exists.")
        admin_client.close()
    except Exception as e:
        logger.error(f"Error checking/creating topic: {e}")
        raise

# --- Hàm gửi dữ liệu vào Kafka (bất đồng bộ) ---
def on_send_success(record_metadata):
    pass

def on_send_error(excp):
    logger.error(f"ERROR sending message to Kafka: {excp}")

def send_to_kafka_async(producer, topic, data, max_retries=3):
    if not data or not producer:
        return False
    for attempt in range(max_retries):
        try:
            producer.send(topic, value=data).add_callback(on_send_success).add_errback(on_send_error)
            return True
        except Exception as e:
            logger.error(f"Attempt {attempt+1}/{max_retries} failed: {e}")
            if attempt < max_retries - 1:
                time.sleep(2 ** attempt)  # Exponential backoff
            else:
                logger.error(f"Failed to send after {max_retries} attempts.")
                return False

# --- Hàm nhập danh sách quốc gia ---
def get_countries():
    logger.info("Nhập danh sách quốc gia (ID và tên). Nhập 'done' khi hoàn tất.")
    countries = []
    while True:
        country_id = input("Nhập CountryID (hoặc 'done' để kết thúc): ")
        if country_id.lower() == 'done':
            break
        country_name = input("Nhập tên quốc gia: ")
        try:
            countries.append({'CountryID': int(country_id), 'Country': country_name})
        except ValueError:
            logger.error("CountryID phải là số. Vui lòng nhập lại.")
    countries_df = pd.DataFrame(countries)
    if countries_df.empty:
        logger.warning("Không có quốc gia nào được nhập.")
    return countries_df

# --- Hàm thu thập đường dẫn giải đấu ---
def scrape_leagues(countries):
    league_name, league_url, league_id = [], [], []
    for i in range(len(countries)):
        url = f"https://www.transfermarkt.com/wettbewerbe/national/wettbewerbe/{countries.loc[i,'CountryID']}"
        logger.info(f"Đang thu thập giải đấu từ {countries.loc[i,'Country']}...")
        try:
            # time.sleep(2)
            page = session.get(url, headers=headers, timeout=10)
            page.raise_for_status()
            soup = BeautifulSoup(page.content, 'html.parser')
            
            league_spans = soup.select('.inline-table a')[1:3]  # Lấy hai giải đấu hàng đầu
            for span in league_spans:
                href = span.get('href')
                league_name.append(span.get('title'))
                league_url.append('https://www.transfermarkt.com' + href + '/plus/?saison_id=')
                league_id_match = re.search(r'/wettbewerb/([A-Z0-9]+)$', href)
                league_id.append(league_id_match.group(1) if league_id_match else None)
        except RequestException as e:
            logger.error(f"Lỗi khi thu thập giải đấu từ {countries.loc[i,'Country']}: {e}")
            continue
    
    leagues = pd.DataFrame({'league_name': league_name, 'league_url': league_url, 'league_id': league_id})
    leagues.to_csv(PATH_TO_LEAGUES, index=False, encoding='utf-8-sig')
    logger.info(f"Đã lưu {len(leagues)} giải đấu vào {PATH_TO_LEAGUES}")
    return leagues

# --- Hàm thu thập đường dẫn CLB ---
def scrape_clubs(leagues):
    club_name, club_url = [], []
    for _, row in leagues.iterrows():
        league = row['league_name']
        base_url = row['league_url']
        for season in range(2024, 2025):  # Chỉ lấy mùa 2024
            url = base_url + str(season)
            logger.info(f"Đang thu thập CLB từ {league} mùa {season}...")
            try:
                # time.sleep(2)
                page = session.get(url, headers=headers, timeout=10)
                page.raise_for_status()
                soup = BeautifulSoup(page.content, 'html.parser')
                
                club_links = soup.select("#yw1 .no-border-links a:nth-child(1)")
                for link in club_links:
                    club_name.append(link.get('title'))
                    club_url.append('https://www.transfermarkt.com' + link.get('href'))
            except RequestException as e:
                logger.error(f"Lỗi khi thu thập CLB từ {league}: {e}")
                continue
    
    clubs = pd.DataFrame({'club_name': club_name, 'club_url': club_url})
    clubs.to_csv(PATH_TO_CLUBS, index=False, encoding='utf-8-sig')
    logger.info(f"Đã lưu {len(clubs)} CLB vào {PATH_TO_CLUBS}")
    return clubs

# --- Hàm thu thập đường dẫn cầu thủ từ CLB (không dùng phân trang) ---
def scrape_players(clubs):
    player_links = set()
    for _, row in clubs.iterrows():
        club_url = row['club_url']
        club_name = row['club_name']
        logger.info(f"Đang thu thập cầu thủ từ {club_name}...")
        try:
            # time.sleep(2)
            response = session.get(club_url, headers=headers, timeout=10)
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")

            players_list = soup.select(".inline-table .hauptlink > a")
            for p in players_list:
                link = p.get('href')
                if link:
                    player_links.add(link)

            logger.info(f"Collected {len(player_links)} unique player links so far for {club_name}.")
        except RequestException as e:
            logger.error(f"Failed to crawl {club_name}: {e}")
            continue

    if player_links:
        df_links = pd.DataFrame(list(player_links), columns=["0"])
        df_links.to_csv(PATH_TO_PLAYERS_LINK, index=False, encoding='utf-8-sig')
        logger.info(f"Saved {len(player_links)} unique player links to {PATH_TO_PLAYERS_LINK}")
    else:
        logger.warning("No player links collected.")

    return list(player_links)

# --- Hàm thu thập dữ liệu cầu thủ và thống kê ---
def scrape_player_and_stats(url):
    try:
        pattern = r"/(\d+)$"
        match = re.search(pattern, url)
        if not match:
            logger.error(f"Invalid URL format: {url}")
            return None
        player_id = match.group(1)
        data = {"player_id": player_id}

        page = session.get(url, headers=headers, timeout=10)
        page.raise_for_status()
        soup = BeautifulSoup(page.content, "html.parser")

        try:
            data["name"] = soup.select_one('h1[class="data-header__headline-wrapper"]').text.split("\n")[-1].strip()
        except (AttributeError, IndexError):
            logger.error(f"Failed to extract name for player ID {player_id}")
            return None

        try:
            data["player_club"] = soup.select_one("span[class='data-header__club']").text.strip()
        except (AttributeError, IndexError):
            logger.error(f"Failed to extract club for player {data['name']}")
            return None

        try:
            age_text = soup.select_one('li[class="data-header__label"]').text.split("\n")[-2].split()[-1].strip("()")
            data["age"] = float(age_text)
        except (AttributeError, ValueError, IndexError):
            logger.error(f"Failed to extract age for player {data['name']}")
            return None

        try:
            data["position"] = soup.find('dd', class_='detail-position__position').text.strip()
        except (AttributeError, IndexError):
            logger.error(f"Failed to extract position for player {data['name']}")
            data["position"] = None

        if data["position"] == "Goalkeeper":
            logger.info(f"Skipping player {data['name']} (ID: {player_id}) because they are a goalkeeper")
            return None

        try:
            market_value = soup.select_one('a[class="data-header__market-value-wrapper"]').text.split(" ")[0].replace('€', '')
            if "m" in market_value:
                data["market_value"] = float(market_value.replace("m", "")) * 1000
            elif "k" in market_value:
                data["market_value"] = float(market_value.replace("k", ""))
            else:
                data["market_value"] = float(market_value)
        except (AttributeError, ValueError, IndexError):
            logger.error(f"Failed to extract market value for player {data['name']}")
            return None

        try:
            data["nationality"] = soup.find('span', itemprop="nationality").text.strip()
        except (AttributeError, IndexError):
            logger.error(f"Failed to extract nationality for player {data['name']}")
            return None

        try:
            height_text = re.search(r"Height:.*?([0-9].*?)\n", soup.text, re.DOTALL).group(1).strip().split(" ")[0].replace(",", ".")
            data["player_height"] = float(height_text)
        except (AttributeError, ValueError, IndexError):
            logger.error(f"Failed to extract height for player {data['name']}")
            return None

        try:
            data["player_agent"] = re.search(r"Agent:.*?([A-z].*?)\n", soup.text, re.DOTALL).group(1).strip()
        except (AttributeError, IndexError):
            data["player_agent"] = "None"
        except ValueError:
            logger.error(f"Failed to extract agent for player {data['name']}")
            return None

        try:
            name_span = soup.find_all('span', class_='info-table__content info-table__content--regular', string=lambda text: text and 'name' in text.lower())
            data["strong_foot"] = soup.select('span[class="info-table__content info-table__content--bold"]')[6 if name_span else 5].text.strip()
        except (AttributeError, IndexError):
            logger.error(f"Failed to extract strong foot for player {data['name']}")
            return None

        try:
            contract_text = re.search(r"Contract expires: (.*)", soup.text).group(1).split()[-1]
            data["contract_value_time"] = float(contract_text) if contract_text.isdigit() else contract_text
        except (AttributeError, IndexError):
            logger.error(f"Failed to extract contract expiry for player {data['name']}")
            return None
        except ValueError:
            data["contract_value_time"] = "None"

        name_hyphenated = url.split('com/')[-1].split('/profil')[0].replace(' ', '-')
        stat_url = f"https://www.transfermarkt.com/{name_hyphenated}/leistungsdatendetails/spieler/{player_id}/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id="
        # time.sleep(2)
        stat_page = session.get(stat_url, headers=headers, timeout=10)
        stat_page.raise_for_status()
        stat_soup = BeautifulSoup(stat_page.content, "html.parser")

        def extract_stat(index, default=0):
            try:
                value = stat_soup.find_all("td", {"class": "zentriert"})[index].text
                return float(value) if value != "-" else default
            except (ValueError, AttributeError, IndexError):
                return None

        try:
            minutes_per_goal = stat_soup.find_all("td", {"class": "rechts"})[1].text.split("'")[0]
            minutes_per_goal = float(minutes_per_goal) if minutes_per_goal != "-" else 0
        except (ValueError, AttributeError, IndexError):
            minutes_per_goal = None

        try:
            minutes_played = stat_soup.find_all("td", {"class": "rechts"})[2].text.split("'")[0]
            minutes_played = float(minutes_played) if minutes_played != "-" else 0
        except (ValueError, AttributeError, IndexError):
            minutes_played = None

        data.update({
            "goalkeeper_or_not": '0',
            "appearances": extract_stat(1),
            "PPG": extract_stat(2),
            "goals": extract_stat(3),
            "assists": extract_stat(4),
            "own_goals": extract_stat(5),
            "substitutions_on": extract_stat(6),
            "substitutions_off": extract_stat(7),
            "yellow_cards": extract_stat(8),
            "second_yellow_cards": extract_stat(9),
            "red_cards": extract_stat(10),
            "penalty_goals": extract_stat(11),
            "minutes_per_goal": minutes_per_goal,
            "minutes_played": minutes_played,
            "goals_conceded": 0.0,
            "clean_sheet": 0.0
        })

        data['crawl_timestamp'] = int(time.time() * 1000)
        data['source'] = url
        return data
    except RequestException as e:
        logger.error(f"Request failed for URL {url}: {e}")
        return None
    except Exception as e:
        logger.error(f"Unexpected error for URL {url}: {e}")
        return None

# --- Hàm chính ---
def main():
    # Nhập danh sách quốc gia
    countries = get_countries()
    if countries.empty:
        logger.error("Không có quốc gia nào được nhập. Thoát chương trình.")
        return

    # Thu thập đường dẫn giải đấu
    leagues = scrape_leagues(countries)
    if leagues.empty:
        logger.error("Không thu thập được giải đấu nào. Thoát chương trình.")
        return

    # Thu thập đường dẫn CLB
    clubs = scrape_clubs(leagues)
    if clubs.empty:
        logger.error("Không thu thập được CLB nào. Thoát chương trình.")
        return

    # Thu thập đường dẫn cầu thủ
    player_links = scrape_players(clubs)
    if not player_links:
        logger.error("Không thu thập được liên kết cầu thủ nào. Thoát chương trình.")
        return

    # Kiểm tra và tạo Kafka topic
    check_and_create_topic()

    # Khởi tạo Kafka producer
    try:
        logger.info(f"Connecting to Kafka broker at {KAFKA_BROKER_URL}...")
        global producer
        producer = KafkaProducer(
            bootstrap_servers=[KAFKA_BROKER_URL],
            value_serializer=lambda v: json.dumps(v, ensure_ascii=False).encode('utf-8'),
            retries=5,
            acks='all'
        )
        logger.info("Successfully connected to Kafka.")
    except Exception as e:
        logger.error(f"CRITICAL: Error connecting to Kafka: {e}")
        return

    # Khởi tạo DataFrame cho backup
    columns = [
        "player_id", "name", "player_club", "age", "position", "goalkeeper_or_not",
        "market_value", "nationality", "player_height", "player_agent", "strong_foot",
        "contract_value_time", "appearances", "PPG", "goals", "assists", "own_goals",
        "substitutions_on", "substitutions_off", "yellow_cards", "second_yellow_cards",
        "red_cards", "penalty_goals", "minutes_per_goal", "minutes_played",
        "goals_conceded", "clean_sheet", "crawl_timestamp", "source"
    ]
    final_data = pd.DataFrame(columns=columns)

    # Biến đếm số lần gửi Kafka
    successful_sends_attempted = 0
    failed_prepares = 0

    try:
        # Xử lý từng cầu thủ
        for i, link in enumerate(player_links):
            url = f"https://www.transfermarkt.com{link}"
            logger.info(f"Scraping player {i+1}/{len(player_links)}: {url}")
            player_data = scrape_player_and_stats(url)
            if player_data is None:
                logger.warning(f"Skipping player at index {i} due to scraping error or goalkeeper")
                continue

            # Gửi dữ liệu vào Kafka
            if send_to_kafka_async(producer, KAFKA_TOPIC, player_data):
                successful_sends_attempted += 1
                logger.info(f"Successfully sent data for player ID {player_data['player_id']} to Kafka")
            else:
                failed_prepares += 1
                logger.error(f"Failed to send data for player ID {player_data['player_id']} to Kafka")

            # Thêm vào DataFrame
            final_data = pd.concat([final_data, pd.DataFrame([player_data])], ignore_index=True)

            # Lưu vào CSV sau mỗi 10 cầu thủ
            if (i + 1) % 10 == 0:
                final_data.to_csv(PATH_TO_FINAL_DATA, index=False, encoding='utf-8-sig')
                producer.flush()
                logger.info(f"Saved {i+1} players to {PATH_TO_FINAL_DATA}")

            # time.sleep(2)

    finally:
        logger.info("-" * 30)
        logger.info("Crawl loop finished.")
        logger.info(f"Total Kafka send attempts prepared: {successful_sends_attempted}")
        logger.info(f"Total Kafka send preparation failures: {failed_prepares}")

        # Lưu dữ liệu lần cuối
        final_data.to_csv(PATH_TO_FINAL_DATA, index=False, encoding='utf-8-sig')
        logger.info(f"Final data saved to {PATH_TO_FINAL_DATA}")

        # Flush và đóng producer
        if producer:
            logger.info("Flushing Kafka producer (waiting for pending messages)...")
            try:
                producer.flush(timeout=60)
                logger.info("Kafka producer flushed.")
            except Exception as flush_e:
                logger.error(f"ERROR during producer flush: {flush_e}")
            finally:
                logger.info("Closing Kafka producer.")
                producer.close()

        logger.info("Script finished.")

if __name__ == "__main__":
    main()
    # country = pd.DataFrame([
    #     {'CountryID': 189, 'Country': 'England'},
    #     {'CountryID': 40, 'Country': 'Germany'},
    #     {'CountryID': 75, 'Country': 'Italy'},
    #     {'CountryID': 50, 'Country': 'France'},
    #     {'CountryID': 157, 'Country': 'Spain'}
    # ])
# Out:
# 2025-05-26 07:24:13,570 - INFO - Nhập danh sách quốc gia (ID và tên). Nhập 'done' khi hoàn tất.
# 2025-05-26 07:24:36,898 - INFO - Đang thu thập giải đấu từ England...
# 2025-05-26 07:24:38,081 - INFO - Đang thu thập giải đấu từ Germany...
# 2025-05-26 07:24:42,057 - INFO - Đang thu thập giải đấu từ Italy...
# 2025-05-26 07:24:43,255 - INFO - Đã lưu 6 giải đấu vào Leagues.csv
# 2025-05-26 07:24:43,256 - INFO - Đang thu thập CLB từ Premier League mùa 2024...
# 2025-05-26 07:24:45,834 - INFO - Đang thu thập CLB từ None mùa 2024...
# 2025-05-26 07:24:47,396 - INFO - Đang thu thập CLB từ Bundesliga mùa 2024...
# 2025-05-26 07:24:48,603 - INFO - Đang thu thập CLB từ None mùa 2024...
# 2025-05-26 07:24:50,096 - INFO - Đang thu thập CLB từ Serie A mùa 2024...
# 2025-05-26 07:24:51,790 - INFO - Đang thu thập CLB từ None mùa 2024...
# 2025-05-26 07:24:55,773 - INFO - Đã lưu 120 CLB vào Clubs.csv
# 2025-05-26 07:24:55,774 - INFO - Đang thu thập cầu thủ từ Manchester City...
# 2025-05-26 07:24:57,321 - INFO - Collected 28 unique player links so far for Manchester City.
# 2025-05-26 07:24:57,322 - INFO - Đang thu thập cầu thủ từ Arsenal FC...
# 2025-05-26 07:25:07,332 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /fc-arsenal/startseite/verein/11/saison_id/2024
# 2025-05-26 07:25:09,179 - INFO - Collected 52 unique player links so far for Arsenal FC.
# 2025-05-26 07:25:09,179 - INFO - Đang thu thập cầu thủ từ Liverpool FC...
# 2025-05-26 07:25:10,831 - INFO - Collected 77 unique player links so far for Liverpool FC.
# 2025-05-26 07:25:10,832 - INFO - Đang thu thập cầu thủ từ Chelsea FC...
# 2025-05-26 07:25:12,505 - INFO - Collected 107 unique player links so far for Chelsea FC.
# 2025-05-26 07:25:12,505 - INFO - Đang thu thập cầu thủ từ Tottenham Hotspur...
# 2025-05-26 07:25:14,171 - INFO - Collected 137 unique player links so far for Tottenham Hotspur.
# 2025-05-26 07:25:14,172 - INFO - Đang thu thập cầu thủ từ Manchester United...
# 2025-05-26 07:25:24,187 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /manchester-united/startseite/verein/985/saison_id/2024
# 2025-05-26 07:25:25,848 - INFO - Collected 164 unique player links so far for Manchester United.
# 2025-05-26 07:25:25,849 - INFO - Đang thu thập cầu thủ từ Newcastle United...
# 2025-05-26 07:25:27,341 - INFO - Collected 191 unique player links so far for Newcastle United.
# 2025-05-26 07:25:27,342 - INFO - Đang thu thập cầu thủ từ Aston Villa...
# 2025-05-26 07:25:37,361 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /aston-villa/startseite/verein/405/saison_id/2024
# 2025-05-26 07:25:37,920 - INFO - Collected 215 unique player links so far for Aston Villa.
# 2025-05-26 07:25:37,921 - INFO - Đang thu thập cầu thủ từ Brighton & Hove Albion...
# 2025-05-26 07:25:39,598 - INFO - Collected 243 unique player links so far for Brighton & Hove Albion.
# 2025-05-26 07:25:39,600 - INFO - Đang thu thập cầu thủ từ West Ham United...
# 2025-05-26 07:25:41,733 - INFO - Collected 270 unique player links so far for West Ham United.
# 2025-05-26 07:25:41,735 - INFO - Đang thu thập cầu thủ từ Nottingham Forest...
# 2025-05-26 07:25:43,718 - INFO - Collected 294 unique player links so far for Nottingham Forest.
# 2025-05-26 07:25:43,718 - INFO - Đang thu thập cầu thủ từ Crystal Palace...
# 2025-05-26 07:25:45,633 - INFO - Collected 321 unique player links so far for Crystal Palace.
# 2025-05-26 07:25:45,634 - INFO - Đang thu thập cầu thủ từ AFC Bournemouth...
# 2025-05-26 07:25:47,867 - INFO - Collected 346 unique player links so far for AFC Bournemouth.
# 2025-05-26 07:25:47,868 - INFO - Đang thu thập cầu thủ từ Brentford FC...
# 2025-05-26 07:25:51,221 - INFO - Collected 372 unique player links so far for Brentford FC.
# 2025-05-26 07:25:51,222 - INFO - Đang thu thập cầu thủ từ Wolverhampton Wanderers...
# 2025-05-26 07:25:53,400 - INFO - Collected 403 unique player links so far for Wolverhampton Wanderers.
# 2025-05-26 07:25:53,400 - INFO - Đang thu thập cầu thủ từ Everton FC...
# 2025-05-26 07:25:55,603 - INFO - Collected 428 unique player links so far for Everton FC.
# 2025-05-26 07:25:55,603 - INFO - Đang thu thập cầu thủ từ Fulham FC...
# 2025-05-26 07:26:05,612 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /fc-fulham/startseite/verein/931/saison_id/2024
# 2025-05-26 07:26:07,512 - INFO - Collected 454 unique player links so far for Fulham FC.
# 2025-05-26 07:26:07,512 - INFO - Đang thu thập cầu thủ từ Ipswich Town...
# 2025-05-26 07:26:09,742 - INFO - Collected 483 unique player links so far for Ipswich Town.
# 2025-05-26 07:26:09,742 - INFO - Đang thu thập cầu thủ từ Southampton FC...
# 2025-05-26 07:26:11,429 - INFO - Collected 513 unique player links so far for Southampton FC.
# 2025-05-26 07:26:11,431 - INFO - Đang thu thập cầu thủ từ Leicester City...
# 2025-05-26 07:26:13,312 - INFO - Collected 542 unique player links so far for Leicester City.
# 2025-05-26 07:26:13,312 - INFO - Đang thu thập cầu thủ từ Burnley FC...
# 2025-05-26 07:26:14,313 - INFO - Collected 572 unique player links so far for Burnley FC.
# 2025-05-26 07:26:14,313 - INFO - Đang thu thập cầu thủ từ Leeds United...
# 2025-05-26 07:26:16,023 - INFO - Collected 596 unique player links so far for Leeds United.
# 2025-05-26 07:26:16,023 - INFO - Đang thu thập cầu thủ từ Sunderland AFC...
# 2025-05-26 07:26:17,128 - INFO - Collected 624 unique player links so far for Sunderland AFC.
# 2025-05-26 07:26:17,128 - INFO - Đang thu thập cầu thủ từ Sheffield United...
# 2025-05-26 07:26:18,118 - INFO - Collected 653 unique player links so far for Sheffield United.
# 2025-05-26 07:26:18,119 - INFO - Đang thu thập cầu thủ từ Middlesbrough FC...
# 2025-05-26 07:26:19,439 - INFO - Collected 680 unique player links so far for Middlesbrough FC.
# 2025-05-26 07:26:19,439 - INFO - Đang thu thập cầu thủ từ Norwich City...
# 2025-05-26 07:26:20,776 - INFO - Collected 709 unique player links so far for Norwich City.
# 2025-05-26 07:26:20,776 - INFO - Đang thu thập cầu thủ từ Luton Town...
# 2025-05-26 07:26:22,420 - INFO - Collected 740 unique player links so far for Luton Town.
# 2025-05-26 07:26:22,420 - INFO - Đang thu thập cầu thủ từ Coventry City...
# 2025-05-26 07:26:24,538 - INFO - Collected 767 unique player links so far for Coventry City.
# 2025-05-26 07:26:24,538 - INFO - Đang thu thập cầu thủ từ West Bromwich Albion...
# 2025-05-26 07:26:34,548 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /west-bromwich-albion/startseite/verein/984/saison_id/2024
# 2025-05-26 07:26:35,987 - INFO - Collected 792 unique player links so far for West Bromwich Albion.
# 2025-05-26 07:26:35,987 - INFO - Đang thu thập cầu thủ từ Hull City...
# 2025-05-26 07:26:46,017 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /hull-city/startseite/verein/3008/saison_id/2024
# 2025-05-26 07:26:48,256 - INFO - Collected 822 unique player links so far for Hull City.
# 2025-05-26 07:26:48,257 - INFO - Đang thu thập cầu thủ từ Stoke City...
# 2025-05-26 07:26:58,271 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /stoke-city/startseite/verein/512/saison_id/2024
# 2025-05-26 07:26:59,807 - INFO - Collected 852 unique player links so far for Stoke City.
# 2025-05-26 07:26:59,807 - INFO - Đang thu thập cầu thủ từ Blackburn Rovers...
# 2025-05-26 07:27:09,822 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /blackburn-rovers/startseite/verein/164/saison_id/2024
# 2025-05-26 07:27:21,897 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /blackburn-rovers/startseite/verein/164/saison_id/2024
# 2025-05-26 07:27:23,585 - INFO - Collected 880 unique player links so far for Blackburn Rovers.
# 2025-05-26 07:27:23,585 - INFO - Đang thu thập cầu thủ từ Queens Park Rangers...
# 2025-05-26 07:27:24,803 - INFO - Collected 910 unique player links so far for Queens Park Rangers.
# 2025-05-26 07:27:24,803 - INFO - Đang thu thập cầu thủ từ Cardiff City...
# 2025-05-26 07:27:34,823 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /cardiff-city/startseite/verein/603/saison_id/2024
# 2025-05-26 07:27:46,885 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /cardiff-city/startseite/verein/603/saison_id/2024
# 2025-05-26 07:27:49,111 - INFO - Collected 938 unique player links so far for Cardiff City.
# 2025-05-26 07:27:49,113 - INFO - Đang thu thập cầu thủ từ Watford FC...
# 2025-05-26 07:27:59,119 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /fc-watford/startseite/verein/1010/saison_id/2024
# 2025-05-26 07:28:00,201 - INFO - Collected 962 unique player links so far for Watford FC.
# 2025-05-26 07:28:00,202 - INFO - Đang thu thập cầu thủ từ Bristol City...
# 2025-05-26 07:28:10,219 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /bristol-city/startseite/verein/698/saison_id/2024
# 2025-05-26 07:28:12,101 - INFO - Collected 986 unique player links so far for Bristol City.
# 2025-05-26 07:28:12,101 - INFO - Đang thu thập cầu thủ từ Swansea City...
# 2025-05-26 07:28:13,641 - INFO - Collected 1010 unique player links so far for Swansea City.
# 2025-05-26 07:28:13,641 - INFO - Đang thu thập cầu thủ từ Preston North End...
# 2025-05-26 07:28:15,754 - INFO - Collected 1037 unique player links so far for Preston North End.
# 2025-05-26 07:28:15,754 - INFO - Đang thu thập cầu thủ từ Millwall FC...
# 2025-05-26 07:28:17,617 - INFO - Collected 1071 unique player links so far for Millwall FC.
# 2025-05-26 07:28:17,617 - INFO - Đang thu thập cầu thủ từ Sheffield Wednesday...
# 2025-05-26 07:28:19,088 - INFO - Collected 1100 unique player links so far for Sheffield Wednesday.
# 2025-05-26 07:28:19,099 - INFO - Đang thu thập cầu thủ từ Plymouth Argyle...
# 2025-05-26 07:28:20,703 - INFO - Collected 1129 unique player links so far for Plymouth Argyle.
# 2025-05-26 07:28:20,703 - INFO - Đang thu thập cầu thủ từ Derby County...
# 2025-05-26 07:28:22,473 - INFO - Collected 1161 unique player links so far for Derby County.
# 2025-05-26 07:28:22,473 - INFO - Đang thu thập cầu thủ từ Portsmouth FC...
# 2025-05-26 07:28:32,501 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /fc-portsmouth/startseite/verein/1020/saison_id/2024
# 2025-05-26 07:28:44,572 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /fc-portsmouth/startseite/verein/1020/saison_id/2024
# 2025-05-26 07:28:58,642 - WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /fc-portsmouth/startseite/verein/1020/saison_id/2024
# 2025-05-26 07:29:00,653 - INFO - Collected 1195 unique player links so far for Portsmouth FC.
# 2025-05-26 07:29:00,653 - INFO - Đang thu thập cầu thủ từ Oxford United...
# 2025-05-26 07:29:02,345 - INFO - Collected 1225 unique player links so far for Oxford United.
# 2025-05-26 07:29:02,345 - INFO - Đang thu thập cầu thủ từ Bayern Munich...
# 2025-05-26 07:29:03,296 - INFO - Collected 1251 unique player links so far for Bayern Munich.
# 2025-05-26 07:29:03,296 - INFO - Đang thu thập cầu thủ từ Bayer 04 Leverkusen...
# 2025-05-26 07:29:04,255 - INFO - Collected 1277 unique player links so far for Bayer 04 Leverkusen.
# 2025-05-26 07:29:04,271 - INFO - Đang thu thập cầu thủ từ RB Leipzig...
# 2025-05-26 07:29:05,175 - INFO - Collected 1303 unique player links so far for RB Leipzig.
# 2025-05-26 07:29:05,184 - INFO - Đang thu thập cầu thủ từ Borussia Dortmund...
# 2025-05-26 07:29:06,988 - INFO - Collected 1331 unique player links so far for Borussia Dortmund.
# 2025-05-26 07:29:06,990 - INFO - Đang thu thập cầu thủ từ VfB Stuttgart...
# 2025-05-26 07:29:07,943 - INFO - Collected 1363 unique player links so far for VfB Stuttgart.
# 2025-05-26 07:29:07,943 - INFO - Đang thu thập cầu thủ từ Eintracht Frankfurt...
# 2025-05-26 07:29:09,934 - INFO - Collected 1390 unique player links so far for Eintracht Frankfurt.
# 2025-05-26 07:29:09,934 - INFO - Đang thu thập cầu thủ từ VfL Wolfsburg...
# 2025-05-26 07:29:11,438 - INFO - Collected 1420 unique player links so far for VfL Wolfsburg.
# 2025-05-26 07:29:11,438 - INFO - Đang thu thập cầu thủ từ TSG 1899 Hoffenheim...
# 2025-05-26 07:29:12,562 - INFO - Collected 1453 unique player links so far for TSG 1899 Hoffenheim.
# 2025-05-26 07:29:12,562 - INFO - Đang thu thập cầu thủ từ SC Freiburg...
# 2025-05-26 07:29:22,573 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /sc-freiburg/startseite/verein/60/saison_id/2024
# 2025-05-26 07:29:23,885 - INFO - Collected 1480 unique player links so far for SC Freiburg.
# 2025-05-26 07:29:23,885 - INFO - Đang thu thập cầu thủ từ 1.FSV Mainz 05...
# 2025-05-26 07:29:25,099 - INFO - Collected 1504 unique player links so far for 1.FSV Mainz 05.
# 2025-05-26 07:29:25,099 - INFO - Đang thu thập cầu thủ từ Borussia Mönchengladbach...
# 2025-05-26 07:29:35,109 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /borussia-monchengladbach/startseite/verein/18/saison_id/2024
# 2025-05-26 07:29:36,342 - INFO - Collected 1530 unique player links so far for Borussia Mönchengladbach.
# 2025-05-26 07:29:36,342 - INFO - Đang thu thập cầu thủ từ SV Werder Bremen...
# 2025-05-26 07:29:37,514 - INFO - Collected 1557 unique player links so far for SV Werder Bremen.
# 2025-05-26 07:29:37,514 - INFO - Đang thu thập cầu thủ từ FC Augsburg...
# 2025-05-26 07:29:38,453 - INFO - Collected 1584 unique player links so far for FC Augsburg.
# 2025-05-26 07:29:38,454 - INFO - Đang thu thập cầu thủ từ 1.FC Union Berlin...
# 2025-05-26 07:29:39,253 - INFO - Collected 1611 unique player links so far for 1.FC Union Berlin.
# 2025-05-26 07:29:39,253 - INFO - Đang thu thập cầu thủ từ 1.FC Heidenheim 1846...
# 2025-05-26 07:29:40,972 - INFO - Collected 1639 unique player links so far for 1.FC Heidenheim 1846.
# 2025-05-26 07:29:40,972 - INFO - Đang thu thập cầu thủ từ FC St. Pauli...
# 2025-05-26 07:29:42,433 - INFO - Collected 1673 unique player links so far for FC St. Pauli.
# 2025-05-26 07:29:42,433 - INFO - Đang thu thập cầu thủ từ VfL Bochum...
# 2025-05-26 07:29:44,375 - INFO - Collected 1700 unique player links so far for VfL Bochum.
# 2025-05-26 07:29:44,375 - INFO - Đang thu thập cầu thủ từ Holstein Kiel...
# 2025-05-26 07:29:46,379 - INFO - Collected 1729 unique player links so far for Holstein Kiel.
# 2025-05-26 07:29:46,381 - INFO - Đang thu thập cầu thủ từ 1.FC Köln...
# 2025-05-26 07:29:56,388 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /1-fc-koln/startseite/verein/3/saison_id/2024
# 2025-05-26 07:30:08,490 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /1-fc-koln/startseite/verein/3/saison_id/2024
# 2025-05-26 07:30:10,016 - INFO - Collected 1760 unique player links so far for 1.FC Köln.
# 2025-05-26 07:30:10,016 - INFO - Đang thu thập cầu thủ từ 1.FC Nuremberg...
# 2025-05-26 07:30:11,704 - INFO - Collected 1792 unique player links so far for 1.FC Nuremberg.
# 2025-05-26 07:30:11,705 - INFO - Đang thu thập cầu thủ từ Hamburger SV...
# 2025-05-26 07:30:12,893 - INFO - Collected 1824 unique player links so far for Hamburger SV.
# 2025-05-26 07:30:12,893 - INFO - Đang thu thập cầu thủ từ Hertha BSC...
# 2025-05-26 07:30:22,902 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /hertha-bsc/startseite/verein/44/saison_id/2024
# 2025-05-26 07:30:24,244 - INFO - Collected 1856 unique player links so far for Hertha BSC.
# 2025-05-26 07:30:24,244 - INFO - Đang thu thập cầu thủ từ Fortuna Düsseldorf...
# 2025-05-26 07:30:25,694 - INFO - Collected 1883 unique player links so far for Fortuna Düsseldorf.
# 2025-05-26 07:30:25,694 - INFO - Đang thu thập cầu thủ từ 1.FC Kaiserslautern...
# 2025-05-26 07:30:27,159 - INFO - Collected 1914 unique player links so far for 1.FC Kaiserslautern.
# 2025-05-26 07:30:27,159 - INFO - Đang thu thập cầu thủ từ FC Schalke 04...
# 2025-05-26 07:30:29,143 - INFO - Collected 1949 unique player links so far for FC Schalke 04.
# 2025-05-26 07:30:29,147 - INFO - Đang thu thập cầu thủ từ SC Paderborn 07...
# 2025-05-26 07:30:30,159 - INFO - Collected 1975 unique player links so far for SC Paderborn 07.
# 2025-05-26 07:30:30,159 - INFO - Đang thu thập cầu thủ từ Hannover 96...
# 2025-05-26 07:30:31,606 - INFO - Collected 2002 unique player links so far for Hannover 96.
# 2025-05-26 07:30:31,606 - INFO - Đang thu thập cầu thủ từ SV Darmstadt 98...
# 2025-05-26 07:30:33,310 - INFO - Collected 2031 unique player links so far for SV Darmstadt 98.
# 2025-05-26 07:30:33,310 - INFO - Đang thu thập cầu thủ từ 1.FC Magdeburg...
# 2025-05-26 07:30:43,323 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /1-fc-magdeburg/startseite/verein/187/saison_id/2024
# 2025-05-26 07:30:44,687 - INFO - Collected 2062 unique player links so far for 1.FC Magdeburg.
# 2025-05-26 07:30:44,689 - INFO - Đang thu thập cầu thủ từ SV 07 Elversberg...
# 2025-05-26 07:30:45,895 - INFO - Collected 2088 unique player links so far for SV 07 Elversberg.
# 2025-05-26 07:30:45,900 - INFO - Đang thu thập cầu thủ từ Karlsruher SC...
# 2025-05-26 07:30:47,020 - INFO - Collected 2116 unique player links so far for Karlsruher SC.
# 2025-05-26 07:30:47,022 - INFO - Đang thu thập cầu thủ từ SpVgg Greuther Fürth...
# 2025-05-26 07:30:48,873 - INFO - Collected 2144 unique player links so far for SpVgg Greuther Fürth.
# 2025-05-26 07:30:48,873 - INFO - Đang thu thập cầu thủ từ Eintracht Braunschweig...
# 2025-05-26 07:30:50,447 - INFO - Collected 2174 unique player links so far for Eintracht Braunschweig.
# 2025-05-26 07:30:50,448 - INFO - Đang thu thập cầu thủ từ SSV Ulm 1846...
# 2025-05-26 07:30:51,603 - INFO - Collected 2199 unique player links so far for SSV Ulm 1846.
# 2025-05-26 07:30:51,605 - INFO - Đang thu thập cầu thủ từ SSV Jahn Regensburg...
# 2025-05-26 07:30:53,058 - INFO - Collected 2231 unique player links so far for SSV Jahn Regensburg.
# 2025-05-26 07:30:53,058 - INFO - Đang thu thập cầu thủ từ Preußen Münster...
# 2025-05-26 07:30:54,609 - INFO - Collected 2258 unique player links so far for Preußen Münster.
# 2025-05-26 07:30:54,609 - INFO - Đang thu thập cầu thủ từ Inter Milan...
# 2025-05-26 07:30:55,954 - INFO - Collected 2283 unique player links so far for Inter Milan.
# 2025-05-26 07:30:55,954 - INFO - Đang thu thập cầu thủ từ Juventus FC...
# 2025-05-26 07:30:57,107 - INFO - Collected 2310 unique player links so far for Juventus FC.
# 2025-05-26 07:30:57,107 - INFO - Đang thu thập cầu thủ từ AC Milan...
# 2025-05-26 07:30:57,872 - INFO - Collected 2336 unique player links so far for AC Milan.
# 2025-05-26 07:30:57,872 - INFO - Đang thu thập cầu thủ từ Atalanta BC...
# 2025-05-26 07:30:59,195 - INFO - Collected 2362 unique player links so far for Atalanta BC.
# 2025-05-26 07:30:59,202 - INFO - Đang thu thập cầu thủ từ SSC Napoli...
# 2025-05-26 07:31:09,207 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /ssc-neapel/startseite/verein/6195/saison_id/2024
# 2025-05-26 07:31:10,175 - INFO - Collected 2387 unique player links so far for SSC Napoli.
# 2025-05-26 07:31:10,175 - INFO - Đang thu thập cầu thủ từ AS Roma...
# 2025-05-26 07:31:11,318 - INFO - Collected 2413 unique player links so far for AS Roma.
# 2025-05-26 07:31:11,318 - INFO - Đang thu thập cầu thủ từ SS Lazio...
# 2025-05-26 07:31:12,186 - INFO - Collected 2444 unique player links so far for SS Lazio.
# 2025-05-26 07:31:12,186 - INFO - Đang thu thập cầu thủ từ Bologna FC 1909...
# 2025-05-26 07:31:13,138 - INFO - Collected 2472 unique player links so far for Bologna FC 1909.
# 2025-05-26 07:31:13,138 - INFO - Đang thu thập cầu thủ từ ACF Fiorentina...
# 2025-05-26 07:31:14,020 - INFO - Collected 2497 unique player links so far for ACF Fiorentina.
# 2025-05-26 07:31:14,020 - INFO - Đang thu thập cầu thủ từ Torino FC...
# 2025-05-26 07:31:15,205 - INFO - Collected 2526 unique player links so far for Torino FC.
# 2025-05-26 07:31:15,205 - INFO - Đang thu thập cầu thủ từ Como 1907...
# 2025-05-26 07:31:16,521 - INFO - Collected 2558 unique player links so far for Como 1907.
# 2025-05-26 07:31:16,521 - INFO - Đang thu thập cầu thủ từ Genoa CFC...
# 2025-05-26 07:31:17,618 - INFO - Collected 2587 unique player links so far for Genoa CFC.
# 2025-05-26 07:31:17,618 - INFO - Đang thu thập cầu thủ từ Udinese Calcio...
# 2025-05-26 07:31:19,123 - INFO - Collected 2617 unique player links so far for Udinese Calcio.
# 2025-05-26 07:31:19,124 - INFO - Đang thu thập cầu thủ từ Parma Calcio 1913...
# 2025-05-26 07:31:20,220 - INFO - Collected 2648 unique player links so far for Parma Calcio 1913.
# 2025-05-26 07:31:20,229 - INFO - Đang thu thập cầu thủ từ FC Empoli...
# 2025-05-26 07:31:21,504 - INFO - Collected 2676 unique player links so far for FC Empoli.
# 2025-05-26 07:31:21,504 - INFO - Đang thu thập cầu thủ từ Hellas Verona...
# 2025-05-26 07:31:22,754 - INFO - Collected 2708 unique player links so far for Hellas Verona.
# 2025-05-26 07:31:22,754 - INFO - Đang thu thập cầu thủ từ AC Monza...
# 2025-05-26 07:31:32,765 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /ac-monza/startseite/verein/2919/saison_id/2024
# 2025-05-26 07:31:44,821 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /ac-monza/startseite/verein/2919/saison_id/2024
# 2025-05-26 07:31:58,899 - WARNING - Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /ac-monza/startseite/verein/2919/saison_id/2024
# 2025-05-26 07:32:00,448 - INFO - Collected 2739 unique player links so far for AC Monza.
# 2025-05-26 07:32:00,448 - INFO - Đang thu thập cầu thủ từ Cagliari Calcio...
# 2025-05-26 07:32:01,264 - INFO - Collected 2763 unique player links so far for Cagliari Calcio.
# 2025-05-26 07:32:01,264 - INFO - Đang thu thập cầu thủ từ US Lecce...
# 2025-05-26 07:32:03,023 - INFO - Collected 2797 unique player links so far for US Lecce.
# 2025-05-26 07:32:03,025 - INFO - Đang thu thập cầu thủ từ Venezia FC...
# 2025-05-26 07:32:03,913 - INFO - Collected 2827 unique player links so far for Venezia FC.
# 2025-05-26 07:32:03,913 - INFO - Đang thu thập cầu thủ từ US Sassuolo...
# 2025-05-26 07:32:06,198 - INFO - Collected 2857 unique player links so far for US Sassuolo.
# 2025-05-26 07:32:06,198 - INFO - Đang thu thập cầu thủ từ Pisa Sporting Club...
# 2025-05-26 07:32:08,140 - INFO - Collected 2884 unique player links so far for Pisa Sporting Club.
# 2025-05-26 07:32:08,144 - INFO - Đang thu thập cầu thủ từ Spezia Calcio...
# 2025-05-26 07:32:09,319 - INFO - Collected 2913 unique player links so far for Spezia Calcio.
# 2025-05-26 07:32:09,321 - INFO - Đang thu thập cầu thủ từ Palermo FC...
# 2025-05-26 07:32:19,332 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /palermo-fc/startseite/verein/458/saison_id/2024
# 2025-05-26 07:32:20,778 - INFO - Collected 2939 unique player links so far for Palermo FC.
# 2025-05-26 07:32:20,779 - INFO - Đang thu thập cầu thủ từ UC Sampdoria...
# 2025-05-26 07:32:22,496 - INFO - Collected 2969 unique player links so far for UC Sampdoria.
# 2025-05-26 07:32:22,500 - INFO - Đang thu thập cầu thủ từ US Cremonese...
# 2025-05-26 07:32:24,385 - INFO - Collected 2997 unique player links so far for US Cremonese.
# 2025-05-26 07:32:24,385 - INFO - Đang thu thập cầu thủ từ US Salernitana 1919...
# 2025-05-26 07:32:34,392 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /us-salernitana-1919/startseite/verein/380/saison_id/2024
# 2025-05-26 07:32:37,131 - INFO - Collected 3027 unique player links so far for US Salernitana 1919.
# 2025-05-26 07:32:37,134 - INFO - Đang thu thập cầu thủ từ Frosinone Calcio...
# 2025-05-26 07:32:38,782 - INFO - Collected 3061 unique player links so far for Frosinone Calcio.
# 2025-05-26 07:32:38,782 - INFO - Đang thu thập cầu thủ từ Cesena FC...
# 2025-05-26 07:32:40,431 - INFO - Collected 3090 unique player links so far for Cesena FC.
# 2025-05-26 07:32:40,432 - INFO - Đang thu thập cầu thủ từ Modena FC...
# 2025-05-26 07:32:42,854 - INFO - Collected 3118 unique player links so far for Modena FC.
# 2025-05-26 07:32:42,857 - INFO - Đang thu thập cầu thủ từ SSC Bari...
# 2025-05-26 07:32:44,489 - INFO - Collected 3143 unique player links so far for SSC Bari.
# 2025-05-26 07:32:44,491 - INFO - Đang thu thập cầu thủ từ Brescia Calcio...
# 2025-05-26 07:32:46,149 - INFO - Collected 3168 unique player links so far for Brescia Calcio.
# 2025-05-26 07:32:46,149 - INFO - Đang thu thập cầu thủ từ US Catanzaro...
# 2025-05-26 07:32:47,779 - INFO - Collected 3196 unique player links so far for US Catanzaro.
# 2025-05-26 07:32:47,783 - INFO - Đang thu thập cầu thủ từ SS Juve Stabia...
# 2025-05-26 07:32:49,328 - INFO - Collected 3223 unique player links so far for SS Juve Stabia.
# 2025-05-26 07:32:49,328 - INFO - Đang thu thập cầu thủ từ AC Reggiana 1919...
# 2025-05-26 07:32:59,344 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /ac-reggiana-1919/startseite/verein/5621/saison_id/2024
# 2025-05-26 07:33:11,421 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /ac-reggiana-1919/startseite/verein/5621/saison_id/2024
# 2025-05-26 07:33:15,639 - INFO - Collected 3252 unique player links so far for AC Reggiana 1919.
# 2025-05-26 07:33:15,642 - INFO - Đang thu thập cầu thủ từ Carrarese Calcio 1908...
# 2025-05-26 07:33:18,515 - INFO - Collected 3280 unique player links so far for Carrarese Calcio 1908.
# 2025-05-26 07:33:18,516 - INFO - Đang thu thập cầu thủ từ FC Südtirol...
# 2025-05-26 07:33:20,760 - INFO - Collected 3310 unique player links so far for FC Südtirol.
# 2025-05-26 07:33:20,761 - INFO - Đang thu thập cầu thủ từ Mantova 1911...
# 2025-05-26 07:33:23,092 - INFO - Collected 3338 unique player links so far for Mantova 1911.
# 2025-05-26 07:33:23,092 - INFO - Đang thu thập cầu thủ từ Cosenza Calcio...
# 2025-05-26 07:33:24,739 - INFO - Collected 3367 unique player links so far for Cosenza Calcio.
# 2025-05-26 07:33:24,743 - INFO - Đang thu thập cầu thủ từ AS Cittadella...
# 2025-05-26 07:33:26,645 - INFO - Collected 3397 unique player links so far for AS Cittadella.
# 2025-05-26 07:33:26,660 - INFO - Saved 3397 unique player links to All_Players_Link.csv
# 2025-05-26 07:33:26,669 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 07:33:26,803 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Broker version identified as 2.6
# 2025-05-26 07:33:26,803 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 07:33:26,939 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=1 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 07:33:26,941 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 07:33:26,942 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-05-26 07:33:26,992 - INFO - Topic 'football_players' does not exist. Creating...
# 2025-05-26 07:33:28,035 - INFO - Topic 'football_players' created successfully.
# 2025-05-26 07:33:28,036 - INFO - <BrokerConnection client_id=kafka-python-2.1.5, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-05-26 07:33:28,036 - INFO - Connecting to Kafka broker at localhost:9092...
# 2025-05-26 07:33:28,036 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 07:33:28,083 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <checking_api_versions_recv> [IPv6 ('::1', 9092, 0, 0)]>: Broker version identified as 2.6
# 2025-05-26 07:33:28,083 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 07:33:28,087 - INFO - Successfully connected to Kafka.
# 2025-05-26 07:33:28,093 - INFO - Scraping player 1/3397: https://www.transfermarkt.com/patrick-erras/profil/spieler/193859
# 2025-05-26 07:33:30,635 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=1 host=localhost:9092 <connecting> [IPv6 ('::1', 9092, 0, 0)]>: connecting to localhost:9092 [('::1', 9092, 0, 0) IPv6]
# 2025-05-26 07:33:30,639 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=1 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Connection complete.
# 2025-05-26 07:33:30,639 - INFO - <BrokerConnection client_id=kafka-python-producer-1, node_id=bootstrap-0 host=localhost:9092 <connected> [IPv6 ('::1', 9092, 0, 0)]>: Closing connection.
# 2025-05-26 07:33:30,729 - INFO - Successfully sent data for player ID 193859 to Kafka
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_10784\1145536263.py:432: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   final_data = pd.concat([final_data, pd.DataFrame([player_data])], ignore_index=True)
# 2025-05-26 07:33:30,754 - INFO - Scraping player 2/3397: https://www.transfermarkt.com/leonardo-mancuso/profil/spieler/160344
# 2025-05-26 07:33:33,726 - INFO - Successfully sent data for player ID 160344 to Kafka
# 2025-05-26 07:33:33,732 - INFO - Scraping player 3/3397: https://www.transfermarkt.com/arne-sicker/profil/spieler/244997
# 2025-05-26 07:33:43,749 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /arne-sicker/profil/spieler/244997
# 2025-05-26 07:33:54,238 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /arne-sicker/leistungsdatendetails/spieler/244997/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:34:00,774 - INFO - Successfully sent data for player ID 244997 to Kafka
# 2025-05-26 07:34:00,777 - INFO - Scraping player 4/3397: https://www.transfermarkt.com/flavio-bianchi/profil/spieler/364132
# 2025-05-26 07:34:10,792 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /flavio-bianchi/profil/spieler/364132
# 2025-05-26 07:34:13,162 - INFO - Successfully sent data for player ID 364132 to Kafka
# 2025-05-26 07:34:13,162 - INFO - Scraping player 5/3397: https://www.transfermarkt.com/liam-henderson/profil/spieler/193867
# 2025-05-26 07:34:15,594 - INFO - Successfully sent data for player ID 193867 to Kafka
# 2025-05-26 07:34:15,594 - INFO - Scraping player 6/3397: https://www.transfermarkt.com/niccolo-pisilli/profil/spieler/813137
# 2025-05-26 07:34:26,665 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /niccolo-pisilli/leistungsdatendetails/spieler/813137/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:34:38,722 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /niccolo-pisilli/leistungsdatendetails/spieler/813137/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:34:40,963 - INFO - Successfully sent data for player ID 813137 to Kafka
# 2025-05-26 07:34:40,967 - INFO - Scraping player 7/3397: https://www.transfermarkt.com/john-tolkin/profil/spieler/683812
# 2025-05-26 07:34:42,971 - INFO - Successfully sent data for player ID 683812 to Kafka
# 2025-05-26 07:34:42,978 - INFO - Scraping player 8/3397: https://www.transfermarkt.com/ollie-tanner/profil/spieler/700405
# 2025-05-26 07:34:44,999 - INFO - Successfully sent data for player ID 700405 to Kafka
# 2025-05-26 07:34:45,003 - INFO - Scraping player 9/3397: https://www.transfermarkt.com/tommaso-biasci/profil/spieler/240129
# 2025-05-26 07:34:47,340 - INFO - Successfully sent data for player ID 240129 to Kafka
# 2025-05-26 07:34:47,352 - INFO - Scraping player 10/3397: https://www.transfermarkt.com/boris-mamuzah-lum/profil/spieler/1067659
# 2025-05-26 07:34:57,366 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /boris-mamuzah-lum/profil/spieler/1067659
# 2025-05-26 07:34:59,993 - INFO - Successfully sent data for player ID 1067659 to Kafka
# 2025-05-26 07:35:00,011 - INFO - Saved 10 players to Final_Data.csv
# 2025-05-26 07:35:00,013 - INFO - Scraping player 11/3397: https://www.transfermarkt.com/gabriel-charpentier/profil/spieler/660342
# 2025-05-26 07:35:10,030 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /gabriel-charpentier/profil/spieler/660342
# 2025-05-26 07:35:11,752 - INFO - Successfully sent data for player ID 660342 to Kafka
# 2025-05-26 07:35:11,767 - INFO - Scraping player 12/3397: https://www.transfermarkt.com/jakub-kaminski/profil/spieler/407098
# 2025-05-26 07:35:22,546 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /jakub-kaminski/leistungsdatendetails/spieler/407098/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:35:23,925 - INFO - Successfully sent data for player ID 407098 to Kafka
# 2025-05-26 07:35:23,940 - INFO - Scraping player 13/3397: https://www.transfermarkt.com/joao-pedro/profil/spieler/626724
# 2025-05-26 07:35:34,587 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /joao-pedro/leistungsdatendetails/spieler/626724/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:35:35,941 - INFO - Successfully sent data for player ID 626724 to Kafka
# 2025-05-26 07:35:35,944 - INFO - Scraping player 14/3397: https://www.transfermarkt.com/pietro-comuzzo/profil/spieler/746712
# 2025-05-26 07:35:46,724 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /pietro-comuzzo/leistungsdatendetails/spieler/746712/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:35:58,813 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /pietro-comuzzo/leistungsdatendetails/spieler/746712/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:36:00,447 - INFO - Successfully sent data for player ID 746712 to Kafka
# 2025-05-26 07:36:00,447 - INFO - Scraping player 15/3397: https://www.transfermarkt.com/mathias-lovik/profil/spieler/661212
# 2025-05-26 07:36:01,997 - INFO - Successfully sent data for player ID 661212 to Kafka
# 2025-05-26 07:36:01,997 - INFO - Scraping player 16/3397: https://www.transfermarkt.com/josha-vagnoman/profil/spieler/448258
# 2025-05-26 07:36:04,078 - INFO - Successfully sent data for player ID 448258 to Kafka
# 2025-05-26 07:36:04,086 - INFO - Scraping player 17/3397: https://www.transfermarkt.com/alex-cairns/profil/spieler/194386
# 2025-05-26 07:36:14,094 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /alex-cairns/profil/spieler/194386
# 2025-05-26 07:36:26,163 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /alex-cairns/profil/spieler/194386
# 2025-05-26 07:36:27,156 - INFO - Skipping player Alex Cairns (ID: 194386) because they are a goalkeeper
# 2025-05-26 07:36:27,157 - WARNING - Skipping player at index 16 due to scraping error or goalkeeper
# 2025-05-26 07:36:27,158 - INFO - Scraping player 18/3397: https://www.transfermarkt.com/malachi-boateng/profil/spieler/703475
# 2025-05-26 07:36:29,610 - INFO - Successfully sent data for player ID 703475 to Kafka
# 2025-05-26 07:36:29,615 - INFO - Scraping player 19/3397: https://www.transfermarkt.com/wataru-endo/profil/spieler/146310
# 2025-05-26 07:36:31,463 - INFO - Successfully sent data for player ID 146310 to Kafka
# 2025-05-26 07:36:31,468 - INFO - Scraping player 20/3397: https://www.transfermarkt.com/kristian-pedersen/profil/spieler/331779
# 2025-05-26 07:36:41,473 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /kristian-pedersen/profil/spieler/331779
# 2025-05-26 07:36:43,659 - INFO - Successfully sent data for player ID 331779 to Kafka
# 2025-05-26 07:36:43,677 - INFO - Saved 20 players to Final_Data.csv
# 2025-05-26 07:36:43,678 - INFO - Scraping player 21/3397: https://www.transfermarkt.com/aaron-keller/profil/spieler/727538
# 2025-05-26 07:36:54,691 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /aaron-keller/leistungsdatendetails/spieler/727538/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:37:06,825 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /aaron-keller/leistungsdatendetails/spieler/727538/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:37:07,933 - INFO - Successfully sent data for player ID 727538 to Kafka
# 2025-05-26 07:37:07,939 - INFO - Scraping player 22/3397: https://www.transfermarkt.com/orel-mangala/profil/spieler/289592
# 2025-05-26 07:37:10,070 - INFO - Successfully sent data for player ID 289592 to Kafka
# 2025-05-26 07:37:10,076 - INFO - Scraping player 23/3397: https://www.transfermarkt.com/ibrahim-sulemana/profil/spieler/982267
# 2025-05-26 07:37:12,448 - INFO - Successfully sent data for player ID 982267 to Kafka
# 2025-05-26 07:37:12,452 - INFO - Scraping player 24/3397: https://www.transfermarkt.com/giorgio-cittadini/profil/spieler/616628
# 2025-05-26 07:37:14,230 - INFO - Successfully sent data for player ID 616628 to Kafka
# 2025-05-26 07:37:14,234 - INFO - Scraping player 25/3397: https://www.transfermarkt.com/frank-fielding/profil/spieler/57070
# 2025-05-26 07:37:15,257 - INFO - Skipping player Frank Fielding (ID: 57070) because they are a goalkeeper
# 2025-05-26 07:37:15,258 - WARNING - Skipping player at index 24 due to scraping error or goalkeeper
# 2025-05-26 07:37:15,259 - INFO - Scraping player 26/3397: https://www.transfermarkt.com/philipp-lienhart/profil/spieler/225657
# 2025-05-26 07:37:17,162 - INFO - Successfully sent data for player ID 225657 to Kafka
# 2025-05-26 07:37:17,166 - INFO - Scraping player 27/3397: https://www.transfermarkt.com/robin-himmelmann/profil/spieler/53116
# 2025-05-26 07:37:27,169 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /robin-himmelmann/profil/spieler/53116
# 2025-05-26 07:37:27,886 - INFO - Skipping player Robin Himmelmann (ID: 53116) because they are a goalkeeper
# 2025-05-26 07:37:27,888 - WARNING - Skipping player at index 26 due to scraping error or goalkeeper
# 2025-05-26 07:37:27,888 - INFO - Scraping player 28/3397: https://www.transfermarkt.com/manuel-marras/profil/spieler/198128
# 2025-05-26 07:37:37,904 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /manuel-marras/profil/spieler/198128
# 2025-05-26 07:37:48,800 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /manuel-marras/leistungsdatendetails/spieler/198128/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:37:49,790 - INFO - Successfully sent data for player ID 198128 to Kafka
# 2025-05-26 07:37:49,893 - INFO - Scraping player 29/3397: https://www.transfermarkt.com/leon-opitz/profil/spieler/825073
# 2025-05-26 07:38:00,000 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /leon-opitz/leistungsdatendetails/spieler/825073/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 07:38:00,920 - INFO - Successfully sent data for player ID 825073 to Kafka
# 2025-05-26 07:38:00,925 - INFO - Scraping player 30/3397: https://www.transfermarkt.com/jeremy-sarmiento/profil/spieler/568005
# 2025-05-26 07:38:03,137 - INFO - Successfully sent data for player ID 568005 to Kafka
# 2025-05-26 07:38:03,144 - INFO - Saved 30 players to Final_Data.csv
# 2025-05-26 07:38:03,145 - INFO - Scraping player 31/3397: https://www.transfermarkt.com/felix-agu/profil/spieler/393512
# 2025-05-26 07:38:04,810 - INFO - Successfully sent data for player ID 393512 to Kafka
# ...
# 2025-05-26 09:26:48,089 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /edson-alvarez/leistungsdatendetails/spieler/401356/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:27:00,178 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /edson-alvarez/leistungsdatendetails/spieler/401356/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:27:02,115 - INFO - Successfully sent data for player ID 401356 to Kafka
# 2025-05-26 09:27:02,120 - INFO - Scraping player 856/3397: https://www.transfermarkt.com/josh-tymon/profil/spieler/419929
# 2025-05-26 09:27:12,993 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /josh-tymon/leistungsdatendetails/spieler/419929/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:27:25,066 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /josh-tymon/leistungsdatendetails/spieler/419929/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:27:26,500 - INFO - Successfully sent data for player ID 419929 to Kafka
# 2025-05-26 09:27:26,506 - INFO - Scraping player 857/3397: https://www.transfermarkt.com/mario-gargiulo/profil/spieler/242469
# 2025-05-26 09:27:28,838 - INFO - Successfully sent data for player ID 242469 to Kafka
# 2025-05-26 09:27:28,841 - INFO - Scraping player 858/3397: https://www.transfermarkt.com/marco-john/profil/spieler/450234
# 2025-05-26 09:27:38,971 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /marco-john/leistungsdatendetails/spieler/450234/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:27:40,798 - INFO - Successfully sent data for player ID 450234 to Kafka
# 2025-05-26 09:27:40,802 - INFO - Scraping player 859/3397: https://www.transfermarkt.com/dodo/profil/spieler/401529
# 2025-05-26 09:27:42,767 - INFO - Successfully sent data for player ID 401529 to Kafka
# 2025-05-26 09:27:42,774 - INFO - Scraping player 860/3397: https://www.transfermarkt.com/robert-leipertz/profil/spieler/119120
# 2025-05-26 09:27:53,681 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /robert-leipertz/leistungsdatendetails/spieler/119120/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:27:55,277 - INFO - Successfully sent data for player ID 119120 to Kafka
# 2025-05-26 09:27:55,293 - INFO - Saved 860 players to Final_Data.csv
# 2025-05-26 09:27:55,294 - INFO - Scraping player 861/3397: https://www.transfermarkt.com/jesurun-rak-sakyi/profil/spieler/586834
# 2025-05-26 09:27:57,426 - INFO - Successfully sent data for player ID 586834 to Kafka
# 2025-05-26 09:27:57,431 - INFO - Scraping player 862/3397: https://www.transfermarkt.com/nadir-zortea/profil/spieler/392966
# 2025-05-26 09:27:59,226 - INFO - Successfully sent data for player ID 392966 to Kafka
# 2025-05-26 09:27:59,232 - INFO - Scraping player 863/3397: https://www.transfermarkt.com/ben-gibson/profil/spieler/128904
# 2025-05-26 09:28:01,284 - INFO - Successfully sent data for player ID 128904 to Kafka
# 2025-05-26 09:28:01,287 - INFO - Scraping player 864/3397: https://www.transfermarkt.com/grischa-promel/profil/spieler/234029
# 2025-05-26 09:28:03,305 - INFO - Successfully sent data for player ID 234029 to Kafka
# 2025-05-26 09:28:03,316 - INFO - Scraping player 865/3397: https://www.transfermarkt.com/aaron-ramsey/profil/spieler/646658
# 2025-05-26 09:28:13,329 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /aaron-ramsey/profil/spieler/646658
# 2025-05-26 09:28:25,399 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /aaron-ramsey/profil/spieler/646658
# 2025-05-26 09:28:27,480 - INFO - Successfully sent data for player ID 646658 to Kafka
# 2025-05-26 09:28:27,485 - INFO - Scraping player 866/3397: https://www.transfermarkt.com/lucien-mahovo/profil/spieler/1052890
# 2025-05-26 09:28:28,152 - ERROR - Failed to extract height for player Lucien Mahovo
# 2025-05-26 09:28:28,152 - WARNING - Skipping player at index 865 due to scraping error or goalkeeper
# 2025-05-26 09:28:28,152 - INFO - Scraping player 867/3397: https://www.transfermarkt.com/tom-dele-bashiru/profil/spieler/346472
# 2025-05-26 09:28:30,187 - INFO - Successfully sent data for player ID 346472 to Kafka
# 2025-05-26 09:28:30,201 - INFO - Scraping player 868/3397: https://www.transfermarkt.com/connor-ogilvie/profil/spieler/236509
# 2025-05-26 09:28:40,213 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /connor-ogilvie/profil/spieler/236509
# 2025-05-26 09:28:42,321 - INFO - Successfully sent data for player ID 236509 to Kafka
# 2025-05-26 09:28:42,326 - INFO - Scraping player 869/3397: https://www.transfermarkt.com/sei-muroya/profil/spieler/188910
# 2025-05-26 09:28:44,186 - INFO - Successfully sent data for player ID 188910 to Kafka
# 2025-05-26 09:28:44,192 - INFO - Scraping player 870/3397: https://www.transfermarkt.com/antonio-palumbo/profil/spieler/287863
# 2025-05-26 09:28:46,068 - INFO - Successfully sent data for player ID 287863 to Kafka
# 2025-05-26 09:28:46,085 - INFO - Saved 870 players to Final_Data.csv
# 2025-05-26 09:28:46,086 - INFO - Scraping player 871/3397: https://www.transfermarkt.com/boris-tomiak/profil/spieler/280581
# 2025-05-26 09:28:47,394 - INFO - Successfully sent data for player ID 280581 to Kafka
# 2025-05-26 09:28:47,398 - INFO - Scraping player 872/3397: https://www.transfermarkt.com/mateus-lusuardi/profil/spieler/1159022
# 2025-05-26 09:28:49,298 - INFO - Successfully sent data for player ID 1159022 to Kafka
# 2025-05-26 09:28:49,303 - INFO - Scraping player 873/3397: https://www.transfermarkt.com/marcus-edwards/profil/spieler/314367
# 2025-05-26 09:29:00,036 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /marcus-edwards/leistungsdatendetails/spieler/314367/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:29:02,722 - INFO - Successfully sent data for player ID 314367 to Kafka
# 2025-05-26 09:29:02,726 - INFO - Scraping player 874/3397: https://www.transfermarkt.com/eric-porstner/profil/spieler/1152976
# 2025-05-26 09:29:05,190 - INFO - Successfully sent data for player ID 1152976 to Kafka
# 2025-05-26 09:29:05,194 - INFO - Scraping player 875/3397: https://www.transfermarkt.com/enzo-millot/profil/spieler/569366
# 2025-05-26 09:29:07,040 - INFO - Successfully sent data for player ID 569366 to Kafka
# 2025-05-26 09:29:07,047 - INFO - Scraping player 876/3397: https://www.transfermarkt.com/milos-kerkez/profil/spieler/730861
# 2025-05-26 09:29:08,883 - INFO - Successfully sent data for player ID 730861 to Kafka
# 2025-05-26 09:29:08,887 - INFO - Scraping player 877/3397: https://www.transfermarkt.com/merlin-rohl/profil/spieler/608832
# 2025-05-26 09:29:12,798 - INFO - Successfully sent data for player ID 608832 to Kafka
# 2025-05-26 09:29:12,801 - INFO - Scraping player 878/3397: https://www.transfermarkt.com/domenico-berardi/profil/spieler/177843
# 2025-05-26 09:29:14,548 - INFO - Successfully sent data for player ID 177843 to Kafka
# 2025-05-26 09:29:14,552 - INFO - Scraping player 879/3397: https://www.transfermarkt.com/mark-omahony/profil/spieler/943549
# 2025-05-26 09:29:24,564 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /mark-omahony/profil/spieler/943549
# 2025-05-26 09:29:27,522 - INFO - Successfully sent data for player ID 943549 to Kafka
# 2025-05-26 09:29:27,527 - INFO - Scraping player 880/3397: https://www.transfermarkt.com/jonathan-varane/profil/spieler/812902
# 2025-05-26 09:29:37,541 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /jonathan-varane/profil/spieler/812902
# 2025-05-26 09:29:49,656 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /jonathan-varane/profil/spieler/812902
# 2025-05-26 09:29:52,054 - INFO - Successfully sent data for player ID 812902 to Kafka
# 2025-05-26 09:29:52,074 - INFO - Saved 880 players to Final_Data.csv
# 2025-05-26 09:29:52,075 - INFO - Scraping player 881/3397: https://www.transfermarkt.com/luca-pellegrini/profil/spieler/346567
# 2025-05-26 09:30:02,091 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /luca-pellegrini/profil/spieler/346567
# 2025-05-26 09:30:12,887 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /luca-pellegrini/leistungsdatendetails/spieler/346567/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:30:14,329 - INFO - Successfully sent data for player ID 346567 to Kafka
# 2025-05-26 09:30:14,339 - INFO - Scraping player 882/3397: https://www.transfermarkt.com/gianluca-busio/profil/spieler/504209
# 2025-05-26 09:30:16,372 - INFO - Successfully sent data for player ID 504209 to Kafka
# 2025-05-26 09:30:16,384 - INFO - Scraping player 883/3397: https://www.transfermarkt.com/nicolas-haas/profil/spieler/192638
# 2025-05-26 09:30:18,163 - INFO - Successfully sent data for player ID 192638 to Kafka
# 2025-05-26 09:30:18,163 - INFO - Scraping player 884/3397: https://www.transfermarkt.com/sivert-mannsverk/profil/spieler/510310
# 2025-05-26 09:30:21,066 - INFO - Successfully sent data for player ID 510310 to Kafka
# 2025-05-26 09:30:21,079 - INFO - Scraping player 885/3397: https://www.transfermarkt.com/matteo-pisseri/profil/spieler/168444
# 2025-05-26 09:30:21,765 - INFO - Skipping player Matteo Pisseri (ID: 168444) because they are a goalkeeper
# 2025-05-26 09:30:21,765 - WARNING - Skipping player at index 884 due to scraping error or goalkeeper
# 2025-05-26 09:30:21,765 - INFO - Scraping player 886/3397: https://www.transfermarkt.com/david-wieser/profil/spieler/562255
# 2025-05-26 09:30:32,832 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /david-wieser/leistungsdatendetails/spieler/562255/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:30:34,505 - INFO - Successfully sent data for player ID 562255 to Kafka
# 2025-05-26 09:30:34,510 - INFO - Scraping player 887/3397: https://www.transfermarkt.com/niklas-jahn/profil/spieler/744600
# 2025-05-26 09:30:45,425 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /niklas-jahn/leistungsdatendetails/spieler/744600/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:30:47,009 - INFO - Successfully sent data for player ID 744600 to Kafka
# 2025-05-26 09:30:47,015 - INFO - Scraping player 888/3397: https://www.transfermarkt.com/alexis-mac-allister/profil/spieler/534033
# 2025-05-26 09:30:57,724 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /alexis-mac-allister/leistungsdatendetails/spieler/534033/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:31:09,808 - WARNING - Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /alexis-mac-allister/leistungsdatendetails/spieler/534033/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
# 2025-05-26 09:31:11,045 - INFO - Successfully sent data for player ID 534033 to Kafka
# 2025-05-26 09:31:11,050 - INFO - Scraping player 889/3397: https://www.transfermarkt.com/almugera-kabar/profil/spieler/884820
# 2025-05-26 09:31:14,597 - INFO - Successfully sent data for player ID 884820 to Kafka
# 2025-05-26 09:31:14,601 - INFO - Scraping player 890/3397: https://www.transfermarkt.com/gabe-forsyth/profil/spieler/948932
# 2025-05-26 09:31:17,457 - INFO - Successfully sent data for player ID 948932 to Kafka
# 2025-05-26 09:31:17,482 - INFO - Saved 890 players to Final_Data.csv
# 2025-05-26 09:31:17,484 - INFO - Scraping player 891/3397: https://www.transfermarkt.com/casemiro/profil/spieler/16306
# 2025-05-26 09:31:19,178 - INFO - Successfully sent data for player ID 16306 to Kafka
# 2025-05-26 09:31:19,182 - INFO - Scraping player 892/3397: https://www.transfermarkt.com/pascal-stenzel/profil/spieler/195246
# 2025-05-26 09:31:21,851 - INFO - Successfully sent data for player ID 195246 to Kafka
# 2025-05-26 09:31:21,857 - INFO - Scraping player 893/3397: https://www.transfermarkt.com/ruben-loftus-cheek/profil/spieler/202886
# 2025-05-26 09:31:23,428 - INFO - Successfully sent data for player ID 202886 to Kafka
# 2025-05-26 09:31:23,434 - INFO - Scraping player 894/3397: https://www.transfermarkt.com/alessandro-salvi/profil/spieler/150462
# 2025-05-26 09:31:33,445 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /alessandro-salvi/profil/spieler/150462
# 2025-05-26 09:31:44,205 - WARNING - Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='www.transfermarkt.com', port=443): Read timed out. (read timeout=10)")': /alessandro-salvi/leistungsdatendetails/spieler/150462/plus/1?saison=2024&verein=&liga=&wettbewerb=&pos=&trainer_id=
